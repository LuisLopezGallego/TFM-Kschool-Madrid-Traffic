# %% [markdown]
# # Notebook 1: Data Cleaning and Preparation (1) => Traffic Devices Location

# %% [markdown]
# ### In this notebook we are going to explore and visualize where are located all the devices with the traffic information. With this analisis we are selecting the ones located on the surrounding area of Madrid Central

# %%
import pandas as pd
import numpy as np
import calendar
import datetime
import folium
import zipfile

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Unziping the devices location file previously downloaded on the notebook number 0.

zip_ref = zipfile.ZipFile('DevicesLocation.zip', 'r')
zip_ref.extractall()
zip_ref.close()

# %%
# Reading all the devices.csv files to check that the devices we are going to use where historically available

devices201904 = pd.read_csv('devices201904.csv', sep = ';')
devices201903 = pd.read_csv('devices201903.csv', sep = ';')
devices201902 = pd.read_csv('devices201902.csv', sep = ';')
devices201901 = pd.read_csv('devices201901.csv', sep = ';')
devices201812 = pd.read_csv('devices201812.csv', sep = ';')
devices201811 = pd.read_csv('devices201811.csv', sep = ';')
devices201810 = pd.read_csv('devices201810.csv', sep = ';', encoding = 'ISO-8859-1')
devices201809 = pd.read_csv('devices201809.csv', sep = ';', encoding = 'ISO-8859-1')
devices201808 = pd.read_csv('devices201808.csv', sep = ';', encoding = 'ISO-8859-1')
devices201807 = pd.read_csv('devices201807.csv', sep = ';', encoding = 'ISO-8859-1')
devices201806 = pd.read_csv('devices201806.csv', sep = ';', encoding = 'ISO-8859-1')
devices201805 = pd.read_csv('devices201805.csv', sep = ';', encoding = 'ISO-8859-1')
devices201804 = pd.read_csv('devices201804.csv', sep = ';', encoding = 'ISO-8859-1')
devices201803 = pd.read_csv('devices201803.csv', sep = ';', encoding = 'ISO-8859-1')
devices201802 = pd.read_csv('devices201802.csv', sep = ';')
devices201801 = pd.read_csv('devices201801.csv', sep = ';')
devices201712 = pd.read_csv('devices201712.csv', sep = ';')
devices201711 = pd.read_csv('devices201711.csv', sep = ';')
devices201710 = pd.read_csv('devices201710.csv', sep = ';')

# %%
pd.options.display.max_columns = None

# %% [markdown]
# #### Open some random files of each year to see how they look: if they have the same columns, same column names, same format of the observations...

# %%
devices201710.head()
# Out:
#   cod_cent    id   nombre tipo_elem           st_x          st_y
# 0  PM40752  7131  PM40752      M-30  444530.319970  4.474557e+06
# 1  PM40753  3827  PM40753      M-30  443631.812671  4.474840e+06
# 2  PM32051  6781  PM32051      M-30  437404.581961  4.476520e+06
# 3  PM32351  6782  PM32351      M-30  436942.467563  4.478783e+06
# 4  PM41802  6936  PM41802      M-30  437038.162874  4.473528e+06

# %%
devices201712.head()

# here we see for instance that the column with the coorditantes do not have the same name
# Out:
#   cod_cent    id   nombre tipo_elem                 x                 y
# 0  PM31452  6779  PM31452      M-30  438847,856203077   4469073,6008804
# 1  PM12121  6691  PM12121      M-30  437426,505080303  4476616,89695453
# 2  PM31851  6938  PM31851      M-30  435084,321501257  4472331,07898929
# 3  PM20233  6719  PM20233      M-30  443364,217013281  4479753,76247714
# 4  PM20721  6737  PM20721      M-30  444088,825090821   4474829,8782982

# %%
devices201801.head()
# Out:
#      cod_cent    id      nombre tipo_elem                 x                 y
# 0  04FT74PM01  1006  04FT74PM01      M-30  437526,638490494  4473735,29258508
# 1  04TL40PM01  6900  04TL40PM01      M-30  444605,018839701  4472829,70059244
# 2  10NC18PM01  6893  10NC18PM01      M-30  443179,814891678  4472230,10628528
# 3  10NC76PM01  6891  10NC76PM01      M-30  442865,993297444  4471840,13233655
# 4  10XC82PM01  6892  10XC82PM01      M-30  442820,065833756  4471645,80194813

# %%
devices201807.head()

# from 201807 the column 'nombre' contains the real name of the address where it is located instead of a code or number as before
# Out:
#   tipo_elem    id cod_cent                                             nombre  \
# 0       URB  5385    94001  REAL PINTO S-N(LAGUNA MARQUESADO-LAGUNA MASQUE...
# 1       URB  5009    95028     Pº EXTREMADURA O-E(NAVAS DEL REY-LA MILAGROSA)
# 2       URB  4055    10007          O´Donnell, 16 O-E - Lope de Rueda-Narvaez
# 3       URB  6417    64402  C/, Julian Camarillo - Albadalejo-Av, Canillej...
# 4       URB  3850    01011   (AFOROS) Genova O-E - General CastaÑos-Pl, Colon
#
#                   x                 y  \
# 0  439401,952109883  4464901,55426055
# 1  437213,219154415  4473454,59124041
# 2  442538,122697889  4474769,52907357
# 3  447856,263627938  4476705,65008674
# 4  441254,990156824  4475271,45945618
#
#                                                 geom
# 0  0106000020E66400000100000001030000000100000008...
# 1  0106000020E66400000100000001030000000100000008...
# 2  0106000020E66400000100000001030000000100000008...
# 3  0106000020E66400000100000001030000000100000008...
# 4  0106000020E66400000100000001030000000100000008...

# %%
devices201810.head()

# from 201810 we have not only the coordinates 'utm' but also longitud and latitud which are the ones I will use
# Out:
#   tipo_elem  distrito    id cod_cent  \
# 0       URB       4.0  3840    01001
# 1       URB       4.0  3841    01002
# 2       URB       1.0  3842    01003
# 3       URB       4.0  3843    01004
# 4       URB       4.0  3844    01005
#
#                                               nombre          utm_x  \
# 0   Jose Ortega y Gasset E-O - Pº Castellana-Serrano  441615.343347
# 1   Jose Ortega y Gasset O-E - Serrano-Pº Castellana  441705.882340
# 2                  Pº Recoletos N-S - Almirante-Prim  441319.371258
# 3          Pº Recoletos S-N - Pl. Cibeles- Recoletos  441301.632986
# 4  (AFOROS) Pº Castellana S-N  - Eduardo Dato - P...  441605.765072
#
#           utm_y  longitud    latitud
# 0  4.475768e+06 -3.688323  40.430502
# 1  4.475770e+06 -3.687256  40.430524
# 2  4.474841e+06 -3.691727  40.422132
# 3  4.474764e+06 -3.691929  40.421433
# 4  4.476132e+06 -3.688470  40.433782

# %%
devices201901.head()
# Out:
#   tipo_elem  distrito    id cod_cent  \
# 0       URB       4.0  3840    01001
# 1       URB       4.0  3841    01002
# 2       URB       1.0  3842    01003
# 3       URB       4.0  3843    01004
# 4       URB       4.0  3844    01005
#
#                                               nombre          utm_x  \
# 0   Jose Ortega y Gasset E-O - Pº Castellana-Serrano  441615.343347
# 1   Jose Ortega y Gasset O-E - Serrano-Pº Castellana  441705.882340
# 2                  Pº Recoletos N-S - Almirante-Prim  441319.371258
# 3          Pº Recoletos S-N - Pl. Cibeles- Recoletos  441301.632986
# 4  (AFOROS) Pº Castellana S-N  - Eduardo Dato - P...  441605.765072
#
#           utm_y  longitud    latitud
# 0  4.475768e+06 -3.688323  40.430502
# 1  4.475770e+06 -3.687256  40.430524
# 2  4.474841e+06 -3.691727  40.422132
# 3  4.474764e+06 -3.691929  40.421433
# 4  4.476132e+06 -3.688470  40.433782

# %%
devices201904.head()
# Out:
#   tipo_elem  distrito    id cod_cent  \
# 0       URB       4.0  3840    01001
# 1       URB       4.0  3841    01002
# 2       URB       1.0  3842    01003
# 3       URB       4.0  3843    01004
# 4       URB       4.0  3844    01005
#
#                                               nombre          utm_x  \
# 0   Jose Ortega y Gasset E-O - Pº Castellana-Serrano  441615.343347
# 1   Jose Ortega y Gasset O-E - Serrano-Pº Castellana  441705.882340
# 2                  Pº Recoletos N-S - Almirante-Prim  441319.371258
# 3          Pº Recoletos S-N - Pl. Cibeles- Recoletos  441301.632986
# 4  (AFOROS) Pº Castellana S-N  - Eduardo Dato - P...  441605.765072
#
#           utm_y  longitud    latitud
# 0  4.475768e+06 -3.688323  40.430502
# 1  4.475770e+06 -3.687256  40.430524
# 2  4.474841e+06 -3.691727  40.422132
# 3  4.474764e+06 -3.691929  40.421433
# 4  4.476132e+06 -3.688470  40.433782

# %% [markdown]
# ### Let's start working the data

# %% [markdown]
# #### Despite we have several columns the process is the following:
#     -Concatenate all of them into a unique dataframe
#     -Once we have all of them together filter by URB and URBANOS since I am focusing on an urban location
#     -Take the columns of my interest
#     -Check that the information of each device is historically the same and they have not switched location
#     -If it is the same I will take the latitud and longitud for locate them in a map

# %% [markdown]
# #### 1.Concatenate all of them

# %%
all_devices = pd.concat([devices201904, devices201903, devices201902, devices201903, 
                         devices201812, devices201811, devices201810, devices201809, 
                         devices201808, devices201807, devices201806, devices201805, 
                         devices201804, devices201803, devices201802, devices201801, 
                         devices201712, devices201711, devices201710], sort = False)

# %%
# Due to memory problems with the Kernel, I delete the variables containing each dataset since I have concatenated them

del(devices201710,devices201711, devices201712,devices201801, devices201802, devices201803, devices201804, devices201805,
    devices201806,devices201807,devices201808,devices201809,devices201810,devices201811,devices201812,devices201901,
    devices201902, devices201903, devices201904)

# %%
# Let's see how the dataframe looks

all_devices.head()

# There are some columns with NaN but I don't mind at all since I won't keep because location coordinates are in longitud and latitud
# Out:
#   tipo_elem  distrito    id cod_cent  \
# 0       URB       4.0  3840    01001
# 1       URB       4.0  3841    01002
# 2       URB       1.0  3842    01003
# 3       URB       4.0  3843    01004
# 4       URB       4.0  3844    01005
#
#                                               nombre          utm_x  \
# 0   Jose Ortega y Gasset E-O - Pº Castellana-Serrano  441615.343347
# 1   Jose Ortega y Gasset O-E - Serrano-Pº Castellana  441705.882340
# 2                  Pº Recoletos N-S - Almirante-Prim  441319.371258
# 3          Pº Recoletos S-N - Pl. Cibeles- Recoletos  441301.632986
# 4  (AFOROS) Pº Castellana S-N  - Eduardo Dato - P...  441605.765072
#
#           utm_y  longitud    latitud    x    y geom st_x st_y
# 0  4.475768e+06 -3.688323  40.430502  NaN  NaN  NaN  NaN  NaN
# 1  4.475770e+06 -3.687256  40.430524  NaN  NaN  NaN  NaN  NaN
# 2  4.474841e+06 -3.691727  40.422132  NaN  NaN  NaN  NaN  NaN
# 3  4.474764e+06 -3.691929  40.421433  NaN  NaN  NaN  NaN  NaN
# 4  4.476132e+06 -3.688470  40.433782  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# #### 2. Let's explore the concatenated data

# %%
# Check the values of the column 'tipo_elem'.....i will use only URB and URBANOS

all_devices['tipo_elem'].unique()
# Out:
# array(['URB', 'M30', 'M-30', 'URBANOS'], dtype=object)

# %%
# Checking the NaN values

all_devices.isnull().any()
# Out:
# tipo_elem    False
# distrito      True
# id           False
# cod_cent     False
# nombre       False
# utm_x         True
# utm_y         True
# longitud      True
# latitud       True
# x             True
# y             True
# geom          True
# st_x          True
# st_y          True
# dtype: bool

# %%
all_devices.dtypes
# Out:
# tipo_elem     object
# distrito     float64
# id             int64
# cod_cent      object
# nombre        object
# utm_x        float64
# utm_y        float64
# longitud     float64
# latitud      float64
# x             object
# y             object
# geom          object
# st_x          object
# st_y          object
# dtype: object

# %%
# Having a look only to the urban devices ordered by 'id' to see if the devices have same information historically

all_devices[all_devices['tipo_elem'] == 'URB'].sort_values(by = 'id')
# Out:
#      tipo_elem  distrito     id cod_cent  \
# 868        URB       7.0   3395    23011
# 3193       URB       NaN   3395    23011
# 872        URB       7.0   3395    23011
# 1572       URB       NaN   3395    23011
# 3843       URB       NaN   3395    23011
# 870        URB       7.0   3395    23011
# 2074       URB       NaN   3395    23011
# 1267       URB       NaN   3395    23011
# 870        URB       7.0   3395    23011
# 871        URB       7.0   3395    23011
# 1596       URB       NaN   3395    23011
# 868        URB       7.0   3395    23011
# 871        URB       NaN   3395    23011
# 1177       URB       NaN   3395    23011
# 869        URB       7.0   3395    23011
# 2704       URB       NaN   3395    23011
# 1727       URB       NaN   3395    23011
# 871        URB       NaN   3395    23011
# 869        URB       7.0   3396    23012
# 2075       URB       NaN   3396    23012
# 872        URB       7.0   3396    23012
# 872        URB       NaN   3396    23012
# 871        URB       7.0   3396    23012
# 873        URB       7.0   3396    23012
# 1258       URB       NaN   3396    23012
# 3517       URB       NaN   3396    23012
# 1867       URB       NaN   3396    23012
# 872        URB       NaN   3396    23012
# 870        URB       7.0   3396    23012
# 1153       URB       NaN   3396    23012
# ...        ...       ...    ...      ...
# 3256       URB      10.0  10399    80306
# 2881       URB      19.0  10400    67001
# 2877       URB      19.0  10400    67001
# 2880       URB      19.0  10400    67001
# 2880       URB      19.0  10400    67001
# 1450       URB      17.0  10401    39002
# 1450       URB      17.0  10401    39002
# 1451       URB      17.0  10401    39002
# 1451       URB      17.0  10402    39003
# 1452       URB      17.0  10402    39003
# 1451       URB      17.0  10402    39003
# 1450       URB      17.0  10403    39001
# 1449       URB      17.0  10403    39001
# 1449       URB      17.0  10403    39001
# 3032       URB       8.0  10404    73046
# 3031       URB       8.0  10404    73046
# 3031       URB       8.0  10404    73046
# 3030       URB       8.0  10405    73045
# 3030       URB       8.0  10405    73045
# 3031       URB       8.0  10405    73045
# 3032       URB       8.0  10406    73047
# 3033       URB       8.0  10406    73047
# 3032       URB       8.0  10406    73047
# 1068       URB       2.0  10407    30039
# 1067       URB       2.0  10407    30039
# 1450     EDUARDO BARREIROS S-N(SANTO ISIDRA-EL CASERIO)  440180.364270
# 1450     EDUARDO BARREIROS S-N(SANTO ISIDRA-EL CASERIO)  440180.364270
# 1451     EDUARDO BARREIROS S-N(SANTO ISIDRA-EL CASERIO)  440180.364270
# 1451  EL CASERIO E-O(PICARA MOLINERA-EDUARDO BARREIROS)  440250.148169
# 1452  EL CASERIO E-O(PICARA MOLINERA-EDUARDO BARREIROS)  440250.148169
# 1451  EL CASERIO E-O(PICARA MOLINERA-EDUARDO BARREIROS)  440250.148169
# 1450  EDUARDO BARREIROS N-S(ASOMBRO DAMASCO-EL CASERIO)  440232.532801
# 1449  EDUARDO BARREIROS N-S(ASOMBRO DAMASCO-EL CASERIO)  440232.532801
# 1449  EDUARDO BARREIROS N-S(ASOMBRO DAMASCO-EL CASERIO)  440232.532801
# 3032  MARIA DE MAEZTU S-N(MARIA MONTESSORI-FEDERICA ...  438181.615828
# 3031  MARIA DE MAEZTU S-N(MARIA MONTESSORI-FEDERICA ...  438181.615828
# 3031  MARIA DE MAEZTU S-N(MARIA MONTESSORI-FEDERICA ...  438181.615828
# 3030  MARIA MONTESSORI E-O(MARIA DE MAEZTU-GLORIA FU...  438142.971104
# 3030  MARIA MONTESSORI E-O(MARIA DE MAEZTU-GLORIA FU...  438142.971104
# 3031  MARIA MONTESSORI E-O(MARIA DE MAEZTU-GLORIA FU...  438142.971104
# 3032  MARIA MONTESSORI E-O(ARROYO DEL MONTE-MARIA DE...  438235.234125
# 3033  MARIA MONTESSORI E-O(ARROYO DEL MONTE-MARIA DE...  438235.234125
# 3032  MARIA MONTESSORI E-O(ARROYO DEL MONTE-MARIA DE...  438235.234125
# 1068  VIRGEN DEL PUERTO S-N(GIRO A PTE SEGOVIA)(MANZ...  438812.957012
# 1067  VIRGEN DEL PUERTO S-N(GIRO A PTE SEGOVIA)(MANZ...  438812.957012
# 1067  VIRGEN DEL PUERTO S-N(GIRO A PTE SEGOVIA)(MANZ...  438812.957012
# 1068  PTE SEGOVIA O-E (GIRO IZQDA)(P: EXTREMADURA -P...  438670.965101
# 1069  PTE SEGOVIA O-E (GIRO IZQDA)(P: EXTREMADURA -P...  438670.965101
# 1068  PTE SEGOVIA O-E (GIRO IZQDA)(P: EXTREMADURA -P...  438670.965101
# 398                 P Chopera E-O (Legazpi-Gral Maroto)  440909.665904
#
#              utm_y  longitud    latitud                 x                 y  \
# 868   4.477151e+06 -3.709570  40.442836               NaN               NaN
# 3193           NaN       NaN        NaN  439824,169575011  4477151,28307507
# 872   4.477151e+06 -3.709570  40.442836               NaN               NaN
# 1572           NaN       NaN        NaN  439824,169575011  4477151,28307507
# 3843           NaN       NaN        NaN            439824       4.47715e+06
# 870   4.477151e+06 -3.709570  40.442836               NaN               NaN
# 2074           NaN       NaN        NaN  439824,169575011  4477151,28307507
# 1267           NaN       NaN        NaN  439824,169575011  4477151,28307507
# 870   4.477151e+06 -3.709570  40.442836               NaN               NaN
# 871   4.477151e+06 -3.709570  40.442836               NaN               NaN
# 1596           NaN       NaN        NaN  439824,169575011  4477151,28307507
#
#                                                    geom              st_x  \
# 868                                                 NaN               NaN
# 3193                                                NaN               NaN
# 872                                                 NaN               NaN
# 1572                                                NaN               NaN
# 3843                                                NaN               NaN
# 870                                                 NaN               NaN
# 2074                                                NaN               NaN
# 1267                                                NaN               NaN
# 870                                                 NaN               NaN
# 871                                                 NaN               NaN
# 1596                                                NaN               NaN
# 868                                                 NaN               NaN
# 871                                                 NaN               NaN
# 1177                                                NaN               NaN
# 869                                                 NaN               NaN
# 2704  0106000020E66400000100000001030000000100000008...               NaN
# 1727                                                NaN  439824,169575011
# 871                                                 NaN               NaN
# 869                                                 NaN               NaN
# 2075                                                NaN               NaN
# 872                                                 NaN               NaN
# 872                                                 NaN               NaN
# 871                                                 NaN               NaN
# 873                                                 NaN               NaN
# 1258                                                NaN               NaN
# 3517                                                NaN  439245,077843593
# 1867                                                NaN               NaN
# 872                                                 NaN               NaN
# 870                                                 NaN               NaN
# 1153                                                NaN               NaN
# ...                                                 ...               ...
# 3256                                                NaN               NaN
# 2881                                                NaN               NaN
# 2877                                                NaN               NaN
# 2880                                                NaN               NaN
# 2880                                                NaN               NaN
# 1450                                                NaN               NaN
# 1450                                                NaN               NaN
# 1451                                                NaN               NaN
# 1451                                                NaN               NaN
# 1452                                                NaN               NaN
# 1451                                                NaN               NaN
# 1450                                                NaN               NaN
# 1449                                                NaN               NaN
# 1449                                                NaN               NaN
# 3032                                                NaN               NaN
# 3031                                                NaN               NaN
# 3031                                                NaN               NaN
# 3030                                                NaN               NaN
# 3030                                                NaN               NaN
# 3031                                                NaN               NaN
# 3032                                                NaN               NaN
# 3033                                                NaN               NaN
# 3032                                                NaN               NaN
# 1068                                                NaN               NaN
# 1067                                                NaN               NaN
# 1067                                                NaN               NaN
# 1068                                                NaN               NaN
# 1069                                                NaN               NaN
# 1068                                                NaN               NaN
# 398                                                 NaN               NaN
#
#                   st_y
# 868                NaN
# 3193               NaN
# 872                NaN
# 1572               NaN
# 3843               NaN
# 870                NaN
# 2074               NaN
# 1267               NaN
# 870                NaN
# 871                NaN
# 1596               NaN
# 868                NaN
# 871                NaN
# 1177               NaN
# 869                NaN
# 2704               NaN
# 1727  4477151,28307507
# 871                NaN
# 869                NaN
# 2075               NaN
# 872                NaN
# 872                NaN
# 871                NaN
# 873                NaN
# 1258               NaN
# 3517  4476756,38438309
# 1867               NaN
# 872                NaN
# 870                NaN
# 1153               NaN
# ...                ...
# 3256               NaN
# 2881               NaN
# 2877               NaN
# 2880               NaN
# 2880               NaN
# 1450               NaN
# 1450               NaN
# 1451               NaN
# 1451               NaN
# 1452               NaN
# 1451               NaN
# 1450               NaN
# 1449               NaN
# 1449               NaN
# 3032               NaN
# 3031               NaN
# 3031               NaN
# 3030               NaN
# 3030               NaN
# 3031               NaN
# 3032               NaN
# 3033               NaN
# 3032               NaN
# 1068               NaN
# 1067               NaN
# 1067               NaN
# 1068               NaN
# 1069               NaN
# 1068               NaN
# 398                NaN
#
# [66414 rows x 14 columns]

# %%
# Perform some random checks

all_devices[all_devices['id'] == 10403]
# Out:
#      tipo_elem  distrito     id cod_cent  \
# 1450       URB      17.0  10403    39001
# 1449       URB      17.0  10403    39001
# 1449       URB      17.0  10403    39001
#
#                                                  nombre          utm_x  \
# 1450  EDUARDO BARREIROS N-S(ASOMBRO DAMASCO-EL CASERIO)  440232.532801
# 1449  EDUARDO BARREIROS N-S(ASOMBRO DAMASCO-EL CASERIO)  440232.532801
# 1449  EDUARDO BARREIROS N-S(ASOMBRO DAMASCO-EL CASERIO)  440232.532801
#
#              utm_y  longitud    latitud    x    y geom st_x st_y
# 1450  4.467593e+06 -3.703857  40.356756  NaN  NaN  NaN  NaN  NaN
# 1449  4.467593e+06 -3.703857  40.356756  NaN  NaN  NaN  NaN  NaN
# 1449  4.467593e+06 -3.703857  40.356756  NaN  NaN  NaN  NaN  NaN

# %%
# Selecting columns of interest:
    # distrito: possible interesting info when location
    # id: is the key columns to merge with the traffic information devices.
    # latitud and longitud are the coordinates of the devices
    # nombre: address or where it is located
    # tipo_elem: to filter by urban devices and remove the one for M-30

devices_columns_of_interest = ['distrito', 'id', 'latitud', 'longitud', 'nombre', 'tipo_elem']

# %%
all_devices = all_devices[devices_columns_of_interest]

# %% [markdown]
# #### 3. Prepare a function to apply to the devices dataset in order to to the following actions:
# - order the columns
# - replace the observations of the column tipo_elem URBANOS by URB to have only 1 type of observations
# - filter by URB since as I said I want only urban devices
# - I limit the devices to map because I had problems when mapping them so I reduce a bit the size
# - Order the dataframe by id and then latitud. Thanks to this, for all the devices repeated with NaN values in the latitud column (and consequently in the longitud) will be placed first so I can fill de NaN with the method 'ffill'
# - Once I have them filled, I remove the duplicates to reduce the size of my dataframe
# - Last, there are some ids duplicated but to removed because of little differences in the name (accents, captal letters...) so I select only one of them

# %%
def devices_function(df):
    # indicate the order of the column
    columns_order = ['id','tipo_elem','nombre','distrito', 'latitud', 'longitud']
    # since in 'tipo_elem' there are 2 type of observations for urban devices, I replace one of them
    df['tipo_elem'].replace(to_replace =['URBANOS'], value =['URB'], inplace = True)
    # filering only by urban devices
    df = df[df['tipo_elem'] == 'URB']
    #the code below is to limit the number of devices to a more restricted area in order to map it
    df = df[(df['longitud'] > -3.721657) & (df['longitud'] < -3.662107) & 
            (df['latitud'] < 40.461345) & (df['latitud'] > 40.398607)]
    # ordering by id and 'latitud' for fill the NaN with 'ffill' method
    df = df.sort_values(by = ['id', 'latitud'], axis = 0, ascending = True).reset_index(drop=True)
    # filling NaN values
    df['latitud'] = df['latitud'].fillna(method='ffill')
    df['longitud'] = df['longitud'].fillna(method='ffill')
    df['distrito'] = df['distrito'].fillna(method='ffill')
    # removing duplicates
    df.drop_duplicates(inplace=True)
    # with the code below I select only 1 of the devices that were repeated because they have the same name with little differences...
    # ...as accents, capital letters
    df = df.groupby((df["id"] != df["id"].shift()).cumsum().values).first() 
    # setting new index
    df.reset_index(drop = True)
    
    return df

# %%
# I apply the function devices_function to the dataframe

devices = devices_function(all_devices)

# %% [markdown]
# #### Checking the results

# %%
devices.shape
# Out:
# (1234, 6)

# %%
devices['tipo_elem'].unique()
# Out:
# array(['URB'], dtype=object)

# %%
devices.isnull().any()
# Out:
# distrito     False
# id           False
# latitud      False
# longitud     False
# nombre       False
# tipo_elem    False
# dtype: bool

# %%
pd.options.display.max_rows = None

# %%
# checking there are not ore than 1 devices with same id and different name due to accents or other signs

devices.groupby(['id', 'nombre']).count()
# Out:
#                                                           distrito  latitud  \
# id    nombre
# 3395  SANTANDER S-N (MELQUIADES ALVAREZ-SAN FRANCISCO...         1        1
# 3396  CEA BERMUDEZ E-O (SAN GABRIEL - SAN FRANCISCO D...         1        1
# 3397  CEA BERMUDEZ O-E (ANDRES MELLADO-GUZMAN EL BUENO)          1        1
# 3398  CORAZSN DE MARIA S-N(SANTA HORTENSIA-SANTA RITA)           1        1
# 3399  CORAZSN DE MARIA, 33 N-S(SANTA RITA-SANTA HORTE...         1        1
# 3400  CLARA DEL REY, 23 N-S(SANTA RITA-SANTA HORTENSIA)          1        1
# 3401  CONCEPCION JERSNIMA O-E(SALVADOR -TOLEDO)                  1        1
# 3407  Santa Engracia, 26 S-N - Caracas-Pl. Chamberi              1        1
# 3411  Av.Pablo Iglesias S-N  - San Francisco de Sales...         1        1
# 3412  AV.FEDERICO RUBIO S-N (PABLO IGLESIAS  - ALMANSA)          1        1
# 3413  AV.FEDERICO RUBIO N-S (ARANJUEZ - ALMANSA)                 1        1
# 3417  P: IMPERIAL O-E(JEMENUQO-P: PONTONES)                      1        1
# 3418  P: PONTONES N-S(STA.CASILDA-P: IMPERIAL)                   1        1
# 3424  Bravo Murillo N-S - Fulgencio Miguel-Francos Ro...         1        1
# 3425  Bravo Murillo N-S - Navarra-Castilla                       1        1
# 3426  Bravo Murillo N-S - Castilla-San Raimundo                  1        1
# 3427  Bravo Murillo N-S - San Raimundo-Carolina                  1        1
# 3433  Dr. Esquerdo S-N - Valderribas-Garibay                     1        1
# 3434  Velazquez S-N - Maria Molina-Lopez Hoyos                   1        1
# 3435  Maria Molina, 40 O-E - Velazquez-Nuñez de Balboa           1        1
# 3439  Av.Pablo Iglesias N-S  - Juán Montalvo - Reina ...         1        1
# 3440  MORERAS S-N(RAMIRO MAEZTU-JUAN XXIII)                      1        1
# 3442  MARTMNEZ IZQUIERDO O-E(PILAR DE ZARAGOZA-VILLAF...         1        1
# 3444  (TACTICO) P: MELANCSLICOS S-N(P: IMPERIAL-RONDA...         1        1
# 3448  PADRE DAMIAN S-N (CONCHA ESPINA - RAFAEL SALGADO)          1        1
# 3452  (AFOROS)Principe de Vergara N-S (ES21) - Albert...         1        1
# 3454  Juán de Olías E-O - Infanta Mercedes-Bravo Murillo         1        1
# 3455  Bravo Murillo S-N - Hernani-Palencia                       1        1
# 3456  San Raimundo E-O - Topete-Bravo Murillo                    1        1
# 3460  Alfonso XIII, 51 N-S - Alhelies-Ramon y Cajal              1        1
# 3461  Ramon y Cajal, 69 O-E - Gabriel Galan-Alfonso XIII         1        1
# 3462  Menendez Pelayo, 75 S-N - Amado Nervo-Pl. Niño ...         1        1
# 3463  (AFOROS) Pº Infanta Isabel E-O - Alfonso XII-Gt...         1        1
# 3464  (AFOROS) Pº Infanta Isabel E-O(SUBTERRANEO) - A...         1        1
# 3865  DR ESQUERDO N-S(SAMARIA-NAZARET)(GIRO A ASTROS)            1        1
# 3866  AV. NAZARET O-E(JESUS APRENDIZ-DR. ESQUERDO)               1        1
# 3867  DR. ESQUERDO N-S(MONTANO-GAVINET)                          1        1
# 3868  (TACTICO) LIRA E-O(CRUZ DEL SUR-DR. ESQUERDO)              1        1
# 3869  DR. ESQUERDO S-N (AV. MEDITERRANEO-LIRA)                   1        1
# 3870  AV. MEDITERRANEO E-O(PASO INFERIOR)                        1        1
# 3871  FDEZ. SHAW S-N(FEDERICO MORENO TORROBA-PL. COND...         1        1
# 3872  Dr. Esquerdo S-N - Garibay-Pl. Conde Casal                 1        1
# 3873  AV. MEDITERRANEO O-E(SANCHEZ BARCAIZTEGUI-PL. C...         1        1
# 3874  AV. MEDITERRANEO O-E(PASO INFERIOR)                        1        1
# 3875  ALCALDE SAINZ BARANDA E-O(VAQUERIAS-LOZOYA)                1        1
# 3876  ALCALDE SAINZ BARANDA O-E(LOZOYA-ESPLANDIU)                1        1
# 3877  (TACTICO) MARQUES LOZOYA S-N(ENTRADA ALCALDE SA...         1        1
# 3878  (TACTICO) SALIDA TVE TORRESPANA S-N                        1        1
# 3880  ESTRELLA POLAR E-O(PUENTE M-30 -SIRIO)                     1        1
# 3881  SIRIO S-N(M-30 -ESTRELLA POLAR)                            1        1
# 3882  DR. ESQUERDO S-N(MONEDA-ALCALDE SAINZ BARANDA)             1        1
# 3883  DR. ESQUERDO N-S(MONEDA-SAMARIA)                           1        1
# 3884  DR. ESQUERDO S-N(ASTROS-PEZ VOLADOR)                       1        1
# 3885  DR. ESQUERDO N-S(AV. NAZARET-ARIAS MONTANO)                1        1
# 3886  DR. ESQUERDO S-N(ESTRELLA POLAR-ASTROS)                    1        1
# 3888  (MICRO) PL. CONDE CASAL(ANTES DE GRUPO16)                  1        1
# 3889  (MICRO) PL. CONDE CASAL (ANTES DEL GRUPO 15)               1        1
# 3890  (MICRO) DR. ESQUERDO N-S(DELANTE GRUPO 1 SALIDA)           1        1
# 3891  Av. Ciudad Barcelona E-O - Gutenberg-Julian Gay...         1        1
# 3892  Av. Ciudad Barcelona O-E - Antonio Nebrija-Come...         1        1
# 3893  Av. Menendez Pelayo N-S - Granada-Av. Ciudad Ba...         1        1
# 3894  Av. Ciudad Barcelona O-E - Juan Urbieta-Comercio           1        1
# 3895  (AFOROS) Av. Ciudad Barcelona E-O - El Cafeto-Seco         1        1
# 3896  Seco S-N - Gandia - Av. Ciudad Barcelona                   1        1
# 3897  (TACTICO) Comercio N-S - Av Ciudad Barcelona -T...         1        1
# 3898  Comercio S-N - Av. Ciudad Barcelona-Tellez                 1        1
# 3899  Av.  Mediterraneo E-O - Abtao-Pl. Mariano Cavia            1        1
# 3900  Cavanilles E-O - Narciso Serra-Pl. Mariano Cavia           1        1
# 3901  Menendez Pelayo S-N - Valderribas-Pl. Mariano C...         1        1
# 3902  Av. Mediterraneo E-O - Abtao-Juan Urbieta                  1        1
# 3903  (TACTICO) Dr. Esquerdo N-S - Cavanilles-Valderr...         1        1
# 4312  AUGUSTO FIGUEROA S-N(SAN BARTOLOMI -PELAYO)                1        1
# 4313  Cuesta San Vicente O-E - Bailen-Gran Via                   1        1
# 4314  Bailen S-N - Lateral entrada cruce G.10                    1        1
# 4315  (MICRO) Cuesta San Vicente E-O - Bailen-Gran Via           1        1
# 4316  Ferraz N-S - Lateral entrada cruce G.7                     1        1
# 4317  Cuesta San Vicente, 14 O-E - Arriaza-Bailen                1        1
# 4318  (TACTICO) Salida Jardines Palacio Real -                   1        1
# 4319  Arriaza N-S - Irun-Cuesta San Vicente                      1        1
# 4320  Cuesta San Vicente O-E - Salida Calle 30-Arriaza           1        1
# 4321  CUESTA SAN VICENTE E-O(P: DEL REY-GTA. SAN VICE...         1        1
# 4322  P: DEL REY N-S(IRUN-CUESTA SAN VICENTE)                    1        1
# 4323  P: VIRGEN DEL PUERTO S-N(CDAD PLASENCIA-GTA SAN...         1        1
# 4324  M-30 SALIDA TZNEL O-E(ENTRADA GTA. SAN VICENTE)...         1        1
# 4325  SEGOVIA, 65 E-O(RONDA SEGOVIA-P: VIRGEN DEL PUE...         1        1
# 4326  P: VIRGEN DEL PUERTO, 13 S-N(MANZANARES-SEGOVIA)           1        1
# 4328  RONDA SEGOVIA S-N(ALGECIRAS-SEGOVIA)                       1        1
# 4329  SEGOVIA, 61 O-E(MAZARREDO-RONDA SEGOVIA)                   1        1
# 4330  CUESTA DE LA VEGA N-S(CDAD.DE PLASENCIA-SEGOVIA)           1        1
# 4331  (TACTICO) P: VIRGEN DEL PUERTO N-E(GIRO A CDAD....         1        1
# 4332  (TACTICO) Mozart N-S (entrada cruce) - (TACTICO...         1        1
# 4333  (MICRO) Cuesta San Vicente S-N(Delante G.2)(P.M...         1        1
# 4334  (MICRO) Cuesta San Vicente S-N - Giro a Ferraz ...         1        1
# 4335  (MICRO) Cuesta San Vicente S-N(Delante G. 4)(P....         1        1
# 4336  (MICRO) Cuesta San Vicente N-S(Delante G.5)(P.M...         1        1
# 4337  FERNANDEZ DE LOS RIOS O-E(PRINCESA-ARCIPRESTE D...         1        1
# 4338  PRINCESA S-N(PL. MONCLOA-P: MORET)                         1        1
# 4339  PRINCESA N-S(GIRO IZQDA. FERNANDO EL CATSLICO)             1        1
# 4340  P: MORET  O-E(MARTIN DE LOS HEROS-PRINCESA)                1        1
# 4341  PRINCESA S-N(MELENDEZ VALDES-PL. MONCLOA)                  1        1
# 4342  MELENDEZ VALDES E-O(ARCIPRETES DE HITA-PRINCESA)           1        1
# 4343  PRINCESA N-S(ALTAMIRANO-MARQUES DE URQUIJO)                1        1
# 4345  MARQUES DE URQUIJO O-E(MARTIN DE LOS HEROS-TUTOR)          1        1
# 4346  PRINCESA S-N(ALBERTO AGUILERA-RRODRIGUEZ SAN PE...         1        1
# 4347  MARQUES DE URQUIJO E-O(PRINCESA-TUTOR)                     1        1
# 4348  PRINCESA, 41 N-S(BUEN SUCESO-QUINTANA)                     1        1
# 4349  PRINCESA S-N(SEMINARIO DE NOBLES-SERRANO JOVER)            1        1
# 10084 Alde. Sainz Baranda E-O - Narváez-López de Rueda           1          1
# 10085 Alde. Sainz Baranda E-O - Fernán González -Narváez         1          1
# 10093 Narvaez 68 N-S - Ibiza-Alde.Sainz Baranda                  1          1
# 10098 Principe Vergara N-S - Diego León -Gral Oraá               1          1
# 10099 Principe Vergara N-S(Giro a Maldonado) - Diego ...         1          1
# 10100 (MICRO)Principe Vergara S-N - Marqués Salamanca...         1          1
# 10101 (MICRO)Principe Vergara S-N - Hermosilla -Ayala            1          1
# 10102 (TACTICA)Principe Vergara N-S(Giro a Hermosilla...         1          1
# 10103 Principe Vergara N-S(Giro a Jorge Juan) - Goya ...         1          1
# 10168 C/ Arturo Soria - Emilio Rubin - Emeterio Castaños         1          1
# 10170 Ppe. Vergara N-S(Giro a Gral Oraá) - Maria Moli...         1          1
# 10192 Conde Peñalver N-S - Diego de León-Maldonado               1          1
# 10193 Conde Peñalver N-S(Giro a Maldonado) - (Diego d...         1          1
# 10195 (TACTICO)JUAN XXIII O-E (OLIMPIADA -PABLO IGLES...         1          1
# 10212 AV.PABLO IGLESIAS N-S (JUAN XXIII - ALMANSA)               1          1
# 10216 (TACTICO) SALIDA HOSPITAL CLINICA SAN CARLOS O-E           1          1
# 10217 Alberto Aguilera, 44 E-O(Entrada Tunel) - Blasc...         1          1
# 10218 JERONIMA LLORENTE E-O (ANTURIO -PAMPLONA)                  1          1
# 10219 JERONIMA LLORENTE O-E (WAD-RAS -PAMPLONA)                  1          1
# 10220 PAMPLONA S-N (FERNANDO OSSORIO -JERONIMA LLORENTE)         1          1
# 10221 PAMPLONA N-S(FRANCOS RODRIGUEZ -JERONIMA LLORENTE)         1          1
# 10258 San Bernardo S-N - Palma -Daoiz                            1          1
# 10259 San Bernardo N-S - Daoiz -Palma                            1          1
# 10271 MARQUES DE URQUIJO E-O(GIRO A P.ROSALES)                   1          1
# 10338 QUINTANA O-E (JUAN ALVAREZ MENDIZABAL-FERRAZ)              1          1
# 10339 Quintana E-O - Martin de los Heros-Mendizabal              1          1
# 10385 Gran Via,67 N-S - Dr. Carracedo-Isabel la Catolica         1          1
# 10386 Gran Via,43 N-S - Silva-Jacometrezo                        1          1
# 10387 Gran Via, 40 E-O - Concepción Arenal-Miguel Moya           1          1
# 10388 Gran Vía S-N - Giro a Jacometrezo                          1          1
# 10407 VIRGEN DEL PUERTO S-N(GIRO A PTE SEGOVIA)(MANZA...         1          1

# %% [markdown]
# ### Mapping

# %% [markdown]
# #### Now that I have been more selective with the devices, I put them on a map to view their location and choose the ones I am interested in

# %%
# I prepare the components I will need for the map

devices_name = list(devices['nombre'])
devices_id = devices['id'].astype('str').values.tolist()
devices_coordinates = devices.reset_index()[['latitud', 'longitud']].values.tolist()
devices['label_for_map'] = devices['id'].astype(str) + '-' + devices['nombre'] + '-'+ devices['longitud'].astype(str) + '-' + devices['latitud'].astype(str)
# the line below is ot use as tooltip when plotting the map
devices_label = devices.reset_index()['label_for_map'].values.tolist()

# %%
# Making a map using the folium module
import folium
devices_map = folium.Map(
    location = [40.433775, -3.693790], # Madrid coordinates
    zoom_start = 12.5,
    tiles = 'Stamen Terrain')


for i in range(0,len(devices)):
# Adding markers to the map: watch out,the coordinates must follow always the following order: first latitud and after longitud
    marker = folium.Marker(location = devices_coordinates[i], popup = devices_label[i], tooltip = 'Click for details!')
    marker.add_to(devices_map)
    

devices_map

# Once the map is displayed, by surfing through the map and clicking on each device we get the details the de device in terms..
# ..of id, name, latitud and longitud
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### After searching in the map and reading on the websites where I take the data from, these are the reasons of selecting the devices I mention below:
# - They are categorized as permanent devices (AFOROS). It means they have remain them historically
# - Located in streets surrounding Madrid Central
# - Not only surrounding but also located in streets with a relevan size and traffic
#
# #### In addition to this I select also the device of the Gran Via, one of the most relevant areas in Madrid and in the heart of Madrid Central
#
# #### AROUND MADRID-CENTRAL:
#     4353: Princesa South-North (SN)
#     4354: Princesa North-South (NS)
#
#     4265: Gran Via de San Francisco el Grande South-North (SN)
#     3478: Gran Via de San Francisco el Grande North-South (NS)
#
#     4211: Ronda de Valencia West-East (WE)
#     5104: Ronda de Valencia East-West (EW)
#
#     4386: Alberto Aguilera West-East (WE)
#     4384: Alberto Aguilera East-West (EW)
#
#     3848: Genova East-West (EW)
#     3850: Genova West-East (WE)
#
#     7138: Paseo del Prado South-North (SN)
#     7139: Paseo del Prado North-South (NS)
#
# #### GRAN VIA
#     4301: Gran Via North-South (NS)
#     4305: Gran Via South-North (SN)

# %%
# Save the devices selected
devices_to_analyze = [4353,4354,4265,3478,4211,5104,4386,4384,3848,3850,7138,7139,4301,4305]

# %%
devices.dtypes
# Out:
# distrito         float64
# id                 int64
# latitud          float64
# longitud         float64
# nombre            object
# tipo_elem         object
# label_for_map     object
# dtype: object

# %%
# Create a dataframe with the devices selected previously
devices = devices[devices['id'].isin(devices_to_analyze)].reset_index(drop = True)
devices.head()
# Out:
#    distrito    id    latitud  longitud  \
# 0       1.0  3478  40.407849 -3.712531
# 1       7.0  3848  40.426925 -3.694187
# 2       1.0  3850  40.426004 -3.692525
# 3       2.0  4211  40.405533 -3.700601
# 4       1.0  4265  40.409298 -3.713404
#
#                                               nombre tipo_elem  \
# 0  (AFOROS)GRAN VMA DE SAN FRANCISCO N-S(AGUILA-P...       URB
# 1         (AFOROS) Genova 13 E-O - Zurbano-Campoamor       URB
# 2   (AFOROS) Genova O-E - General Castaños-Pl. Colon       URB
# 3  (AFOROS) RONDA VALENCIA O-E(MESON DE PAREDES-F...       URB
# 4  (AFOROS)Gran Vía San Francisco S-N - San Berna...       URB
#
#                                        label_for_map
# 0  3478-(AFOROS)GRAN VMA DE SAN FRANCISCO N-S(AGU...
# 1  3848-(AFOROS) Genova 13 E-O - Zurbano-Campoamo...
# 2  3850-(AFOROS) Genova O-E - General Castaños-Pl...
# 3  4211-(AFOROS) RONDA VALENCIA O-E(MESON DE PARE...
# 4  4265-(AFOROS)Gran Vía San Francisco S-N - San ...

# %%
len(devices)
# Out:
# 14

# %% [markdown]
# ### Save the final result into a csv

# %%
# Save the final devices to analize on a csv for next steps
devices.to_csv('devices_to_analize.csv', sep = ';')

# %% [markdown]
# #### Move to next notebook number 2
